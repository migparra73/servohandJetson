# %%
import numpy as np
from matplotlib import pyplot as plt
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-vcdzctfc because the default path (/home/javi/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
x = np.linspace(0, 10, 20)
y = x * 10
plt.plot(x, y)
